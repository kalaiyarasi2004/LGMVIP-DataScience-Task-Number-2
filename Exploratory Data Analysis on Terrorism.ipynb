# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("globalterrorismdb_0718dist.csv",encoding='latin1')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10308\2264685797.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("globalterrorismdb_0718dist.csv",encoding='latin1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# 25%         0.000000      78.000000       5.000000      11.510046
# 50%         0.000000      98.000000       6.000000      31.467463
# 75%         0.000000     160.000000      10.000000      34.685087
# max         1.000000    1004.000000      12.000000      74.633553
#
#           longitude    specificity  ...     ransomamt   ransomamtus  \
# count  1.771340e+05  181685.000000  ...  1.350000e+03  5.630000e+02
# mean  -4.586957e+02       1.451452  ...  3.172530e+06  5.784865e+05
# std    2.047790e+05       0.995430  ...  3.021157e+07  7.077924e+06
# min   -8.618590e+07       1.000000  ... -9.900000e+01 -9.900000e+01
# 25%    4.545640e+00       1.000000  ...  0.000000e+00  0.000000e+00
# 50%    4.324651e+01       1.000000  ...  1.500000e+04  0.000000e+00
# 75%    6.871033e+01       1.000000  ...  4.000000e+05  0.000000e+00
# max    1.793667e+02       5.000000  ...  1.000000e+09  1.320000e+08
#
#          ransompaid  ransompaidus  hostkidoutcome     nreleased  \
# count  7.740000e+02    552.000000    10991.000000  10400.000000
# mean   7.179437e+05    240.378623        4.629242    -29.018269
# std    1.014392e+07   2940.967293        2.035360     65.720119
# min   -9.900000e+01    -99.000000        1.000000    -99.000000
# 25%   -9.900000e+01      0.000000        2.000000    -99.000000
# 50%    0.000000e+00      0.000000        4.000000      0.000000
# 75%    1.273412e+03      0.000000        7.000000      1.000000
# max    2.750000e+08  48000.000000        7.000000   2769.000000
#
#              INT_LOG       INT_IDEO       INT_MISC        INT_ANY
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean       -4.543731      -4.464398       0.090010      -3.945952
# std         4.543547       4.637152       0.568457       4.691325
# min        -9.000000      -9.000000      -9.000000      -9.000000
# 25%        -9.000000      -9.000000       0.000000      -9.000000
# 50%        -9.000000      -9.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 77 columns]

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
df=df[['iyear','imonth','iday','country_txt','city','region_txt','latitude','longitude','extended','target1','success','suicide','attacktype1_txt','targtype1_txt','gname','weaptype1_txt','nkill','nwound']]

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'region','attacktype1_txt':'AttackType','target1':'Target',
                  'nkill':'Killed','nwound':'Wounded',
                   'targtype1_txt':'Target_Type','gname':'group_name','weaptype1_txt':'Weapon_type','motive':'Motive',
                  'extended':'Extended','latitude':'Latitude','longitude':'Longitude', 'target1': 'Target','city':'City'}, inplace = True)

# %%
df.head()
# Out:
#    Year  Month  Day             Country           City  \
# 0  1970      7    2  Dominican Republic  Santo Domingo
# 1  1970      0    0              Mexico    Mexico city
# 2  1970      1    0         Philippines        Unknown
# 3  1970      1    0              Greece         Athens
# 4  1970      1    0               Japan        Fukouka
#
#                         region   Latitude   Longitude  Extended  \
# 0  Central America & Caribbean  18.456792  -69.951164         0
# 1                North America  19.371887  -99.086624         0
# 2               Southeast Asia  15.478598  120.599741         0
# 3               Western Europe  37.997490   23.762728         0
# 4                    East Asia  33.580412  130.396361         0
#
#                     Target  success  suicide                      AttackType  \
# 0             Julio Guzman        1        0                   Assassination
# 1  Nadine Chaval, daughter        1        0     Hostage Taking (Kidnapping)
# 2                 Employee        1        0                   Assassination
# 3             U.S. Embassy        1        0               Bombing/Explosion
# 4           U.S. Consulate        1        0  Facility/Infrastructure Attack
#
#                    Target_Type                          group_name  \
# 0  Private Citizens & Property                              MANO-D
# 1      Government (Diplomatic)  23rd of September Communist League
# 2          Journalists & Media                             Unknown
# 3      Government (Diplomatic)                             Unknown
# 4      Government (Diplomatic)                             Unknown
#
#   Weapon_type  Killed  Wounded
# 0     Unknown     1.0      0.0
# 1     Unknown     0.0      0.0
# 2     Unknown     1.0      0.0
# 3  Explosives     NaN      NaN
# 4  Incendiary     NaN      NaN

# %%
df.isnull().sum()
# Out:
# Year               0
# Month              0
# Day                0
# Country            0
# City             435
# region             0
# Latitude        4556
# Longitude       4557
# Extended           0
# Target           638
# success            0
# suicide            0
# AttackType         0
# Target_Type        0
# group_name         0
# Weapon_type        0
# Killed         10313
# Wounded        16311
# dtype: int64

# %%
df['Latitude']=df['Latitude'].fillna(df['Latitude'].mean())
df['Longitude']=df['Longitude'].fillna(df['Longitude'].mean())
df["Killed"]=df["Killed"].fillna(0)
df["Wounded"]=df["Wounded"].fillna(0)
df['Target']=df["Target"].fillna(0)

# %%
df.isnull().sum()
# Out:
# Year             0
# Month            0
# Day              0
# Country          0
# City           435
# region           0
# Latitude         0
# Longitude        0
# Extended         0
# Target           0
# success          0
# suicide          0
# AttackType       0
# Target_Type      0
# group_name       0
# Weapon_type      0
# Killed           0
# Wounded          0
# dtype: int64

# %%
years = pd.DataFrame(df["Year"].value_counts())
years.head(10)
# Out:
#       count
# Year
# 2014  16903
# 2015  14965
# 2016  13587
# 2013  12036
# 2017  10900
# 2012   8522
# 2011   5076
# 1992   5071
# 2010   4826
# 2008   4805

# %%
year_s=df[["Year",'Killed']].groupby("Year").sum().sort_values (by = 'Killed',ascending=False)
year_s.head(10)
# Out:
#        Killed
# Year
# 2014  44490.0
# 2015  38853.0
# 2016  34871.0
# 2017  26445.0
# 2013  22273.0
# 2012  15497.0
# 2007  12824.0
# 1997  10924.0
# 1984  10450.0
# 1992   9742.0

# %%
country = pd.DataFrame(df["Country"].value_counts())
print(" Name of the Countries (most affected by the attacks) : \n")
country.head(10)
# Out:
#  Name of the Countries (most affected by the attacks) :
#                 count
# Country
# Iraq            24636
# Pakistan        14368
# Afghanistan     12731
# India           11960
# Colombia         8306
# Philippines      6908
# Peru             6096
# El Salvador      5320
# United Kingdom   5235
# Turkey           4292

# %%
region = pd.DataFrame(df["region"].value_counts())
print("Regions affected most by the attacks: \n")
region.head()
# Out:
# Regions affected most by the attacks:
#                             count
# region
# Middle East & North Africa  50474
# South Asia                  44974
# South America               18978
# Sub-Saharan Africa          17550
# Western Europe              16639

# %%
City= pd.DataFrame(df['City'].value_counts().drop("Unknown"))
print(" Name of the City (most affected by the attacks) : \n")
City.head(10)
# Out:
#  Name of the City (most affected by the attacks) :
#               count
# City
# Baghdad        7589
# Karachi        2652
# Lima           2359
# Mosul          2265
# Belfast        2171
# Santiago       1621
# Mogadishu      1581
# San Salvador   1558
# Istanbul       1048
# Athens         1019

# %%
attacks = pd.DataFrame(df["AttackType"].value_counts())
attacks
# Out:
#                                      count
# AttackType
# Bombing/Explosion                    88255
# Armed Assault                        42669
# Assassination                        19312
# Hostage Taking (Kidnapping)          11158
# Facility/Infrastructure Attack       10356
# Unknown                               7276
# Unarmed Assault                       1015
# Hostage Taking (Barricade Incident)    991
# Hijacking                              659

# %%
target = pd.DataFrame(df['Target_Type'].value_counts())
target
# Out:
#                                 count
# Target_Type
# Private Citizens & Property     43511
# Military                        27984
# Police                          24506
# Government (General)            21283
# Business                        20669
# Transportation                   6799
# Utilities                        6023
# Unknown                          5898
# Religious Figures/Institutions   4440
# Educational Institution          4322
# Government (Diplomatic)          3573
# Terrorists/Non-State Militia     3039
# Journalists & Media              2948
# Violent Political Party          1866
# Airports & Aircraft              1343
# Telecommunication                1009
# NGO                               970
# Tourists                          440
# Maritime                          351
# Food or Water Supply              317
# Abortion Related                  263
# Other                             137

# %%
weapon = pd.DataFrame(df['Weapon_type'].value_counts())
weapon
# Out:
#                                                     count
# Weapon_type
# Explosives                                          92426
# Firearms                                            58524
# Unknown                                             15157
# Incendiary                                          11135
# Melee                                                3655
# Chemical                                              321
# Sabotage Equipment                                    141
# Vehicle (not to include vehicle-borne explosive...    136
# Other                                                 114
# Biological                                             35
# Fake Weapons                                           33
# Radiological                                           14

# %%
Group=pd.DataFrame(df["group_name"].value_counts().drop('Unknown'))
Group.head(10)
# Out:
#                                                   count
# group_name
# Taliban                                            7478
# Islamic State of Iraq and the Levant (ISIL)        5613
# Shining Path (SL)                                  4555
# Farabundo Marti National Liberation Front (FMLN)   3351
# Al-Shabaab                                         3288
# New People's Army (NPA)                            2772
# Irish Republican Army (IRA)                        2671
# Revolutionary Armed Forces of Colombia (FARC)      2487
# Boko Haram                                         2418
# Kurdistan Workers' Party (PKK)                     2310

# %%
gcv=df[["group_name","Country"]].value_counts().drop("Unknown")
gcv.head(20)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10308\2356500493.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gcv=df[["group_name","Country"]].value_counts().drop("Unknown")
# group_name                                        Country
# Taliban                                           Afghanistan       7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq              4797
# Shining Path (SL)                                 Peru              4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       3330
# Al-Shabaab                                        Somalia           2867
# New People's Army (NPA)                           Philippines       2770
# Irish Republican Army (IRA)                       United Kingdom    2575
# Revolutionary Armed Forces of Colombia (FARC)     Colombia          2468
# Kurdistan Workers' Party (PKK)                    Turkey            2109
# Boko Haram                                        Nigeria           2087
# Basque Fatherland and Freedom (ETA)               Spain             1975
# Communist Party of India - Maoist (CPI-Maoist)    India             1877
# Liberation Tigers of Tamil Eelam (LTTE)           Sri Lanka         1596
# National Liberation Army of Colombia (ELN)        Colombia          1529
# Maoists                                           India             1396
# Tehrik-i-Taliban Pakistan (TTP)                   Pakistan          1335
# Al-Qaida in the Arabian Peninsula (AQAP)          Yemen             1007
# Houthi extremists (Ansar Allah)                   Yemen              908
# Nicaraguan Democratic Force (FDN)                 Nicaragua          886
# Manuel Rodriguez Patriotic Front (FPMR)           Chile              829
# Name: count, dtype: int64

# %%
gcv.head(10).plot(kind ="bar",figsize=(15,6))
plt.title("Countries with most attacks by an individual Groups",fontsize= 20)
plt.xlabel("(Terrorist Group,Country)",fontsize=20)
plt.xticks(fontsize=12)
plt.ylabel("No. of Attacks",fontsize=20)
plt.show()

# %%
attacks.plot(kind="bar",color="cornflowerblue",figsize=(15,6),fontsize=13)
plt.title("Timeline of Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.subplots(figsize=(20, 10))
sns.barplot(x=df['Year'].value_counts()[:10].index, y=df['Killed'].value_counts()[:10].values)
plt.title('No. of Killed Persons in Each Year', fontsize=30)
plt.xlabel('Year', fontsize=20)
plt.ylabel('No. of Killed Persons', fontsize=20)
plt.xticks(fontsize=15, rotation=90)
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10308\2917940505.py:2: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   sns.barplot(x=df['Year'].value_counts()[:10].index, y=df['Killed'].value_counts()[:10].values)
